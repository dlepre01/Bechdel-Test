# %%
pip install names-dataset
# Out:
# Collecting names-dataset
#   Downloading names-dataset-3.1.0.tar.gz (58.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.4/58.4 MB 6.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting pycountry (from names-dataset)
#   Downloading pycountry-24.6.1-py3-none-any.whl (6.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 18.5 MB/s eta 0:00:00
# Building wheels for collected packages: names-dataset
#   Building wheel for names-dataset (setup.py) ... done
#   Created wheel for names-dataset: filename=names_dataset-3.1.0-py3-none-any.whl size=116832757 sha256=6eb107498e0da6c2347c3103e55332a5279169aeb4130a74c84f9ca82c49cd5e
#   Stored in directory: /root/.cache/pip/wheels/cf/f8/43/0c4aba87b34e971e7255a41f11dc0035c5e55b026dc3480986
# Successfully built names-dataset
# Installing collected packages: pycountry, names-dataset
# Successfully installed names-dataset-3.1.0 pycountry-24.6.1

# %%
import requests
from bs4 import BeautifulSoup
from sqlalchemy import create_engine, text
import re
import spacy
from names_dataset import NameDataset
import string
# Creazione del database
engine = create_engine('sqlite:///Bechdel_test.db')

# Funzione per creare le tabelle
def create_tables():
    with engine.connect() as conn:
        conn.execute(text('''
        CREATE TABLE IF NOT EXISTS MOVIE (
            film_id INTEGER PRIMARY KEY,
            titolo TEXT,
            anno INTEGER
        )
        '''))

        conn.execute(text('''
        CREATE TABLE IF NOT EXISTS SCRIPT (
            film_id INTEGER,
            scene_id INTEGER,
            place TEXT,
            scena TEXT,
            personaggi TEXT,
            count_female INTEGER,
            count_male INTEGER,
            nom TEXT,
            count_male_nom INTEGER,
            PRIMARY KEY (film_id, scene_id)
        )
        '''))

        conn.execute(text('''
        CREATE TABLE IF NOT EXISTS CAST (
            film_id INTEGER,
            nome TEXT,
            ruolo TEXT,
            gender TEXT,
            PRIMARY KEY (film_id, nome)
        )
        '''))

create_tables()

# Funzione per dividere lo script mantenendo INT ed EXT
def dividere_script_con_int_ext(script):
    # Carica il modello spaCy
    nlp = spacy.load('en_core_web_sm')

    # Trova le posizioni in cui appare INT o EXT
    int_ext_positions = [match.start() for match in re.finditer(r'\bINT\b|\bEXT\b', script)]
    # Dividi il testo dello script in base alle posizioni trovate
    scene_divise = []
    for start, end in zip([0] + int_ext_positions, int_ext_positions + [len(script)]):
        scena = script[start:end].strip()
        if scena:
            place = scena.split('\n', 1)[0].strip() if '\n' in scena else scena.strip()

            # Estrai solo INT o EXT dalla stringa di place
            match = re.match(r'\b(INT|EXT)\b', place)
            if match:
                place = match.group(0)

            # Controlla se la scena inizia con INT./, EXT./, INT/, o EXT/
            if re.match(r'\b(INT\./|EXT\./|INT/|EXT/)', scena):
                continue  # Salta questa scena
            scena_pulita = re.sub(r'[<>*\d]', '', scena)
            # Estrai i personaggi dalla scena utilizzando spaCy
            doc = nlp(scena)
            personaggi = [ent.text for ent in doc.ents if ent.label_ == "PERSON"]
            scene_divise.append({'place': place, 'scena': scena_pulita, 'personaggi': ' '.join(personaggi)})
    return scene_divise

# Funzione per scaricare lo script da IMSDb e dividerlo in scene
def scarica_e_dividi_script_da_imsdb(titolo_film):
    url = f"https://www.imsdb.com/scripts/{titolo_film.replace(' ', '-')}.html"
    response = requests.get(url)
    if response.status_code == 200:
        soup = BeautifulSoup(response.content, 'html.parser')
        script = soup.find('td', {'class': 'scrtext'}).text
        scene_divise = dividere_script_con_int_ext(script)
        return scene_divise
    else:
        print(f"Errore nel scaricare lo script da IMSDb per il film {titolo_film}")
        return None

# Funzione per scaricare il cast da IMDb

def scarica_cast_da_imdb(imdb_id):
    url = f"https://www.imdb.com/title/{imdb_id}/fullcredits"
    response = requests.get(url)
    if response.status_code == 200:
        soup = BeautifulSoup(response.content, 'html.parser')
        cast_list = []
        roles_seen = set()

        for row in soup.select('.cast_list tr')[1:]:  # Ignore the header row
            columns = row.find_all('td')
            if len(columns) >= 4:
                actor_name = columns[1].get_text(strip=True)
                character_name = columns[3].get_text(strip=True).split(' ')[0]  # Take only the first word of the role

                # Remove all punctuation from the character name
                character_name = character_name.translate(str.maketrans('', '', string.punctuation))

                # Remove trailing 's if present
                character_name = re.sub(r"'s$", "", character_name)

                # Check if the character name has already been seen
                if character_name not in roles_seen:
                    roles_seen.add(character_name)

                    # Exclude roles that are "A", "The", contain numbers, or contain "uncredited"
                    if (character_name.lower() in {"a", "the"} or any(char.isdigit() for char in character_name)
                            or "uncredited" in character_name.lower()):
                        continue  # Skip this row

                    cast_list.append({'name': actor_name, 'role': character_name})

        return cast_list
    else:
        print(f"Error: Unable to fetch data from IMDB for {imdb_id}")
        return []



# Funzione per inserire i dati nel database
def insert_data(data, table_name):
    with engine.begin() as conn:
        if table_name == "SCRIPT":
            conn.execute(text('''
            INSERT INTO SCRIPT (film_id, scene_id, place, scena, personaggi, count_female, count_male, nom, count_male_nom)
            VALUES (:film_id, :scene_id, :place, :scena, :personaggi, :count_female, :count_male, :nom, :count_male_nom)
            '''), data)
        elif table_name == "CAST":
            # Check if the entry already exists before inserting
            existing_entry = conn.execute(text('''
                SELECT 1
                FROM CAST
                WHERE film_id = :film_id AND nome = :nome
            '''), data).fetchone()
            if not existing_entry:  # Insert only if it doesn't exist
                conn.execute(text('''
                INSERT INTO CAST (film_id, nome, ruolo, gender)
                VALUES (:film_id, :nome, :ruolo, :gender)
                '''), data)
        elif table_name == "MOVIE":
            conn.execute(text('''
            INSERT INTO MOVIE (film_id, titolo, anno)
            VALUES (:film_id, :titolo, :anno)
            '''), data)

def pulisci_ruolo(ruolo):
    return re.sub(r'\([^)]*\)', '', ruolo).strip()

# Funzione per pulire la scena
def pulisci_scena(scena):
    return scena.split('\n', 1)[1].strip() if '\n' in scena else scena.strip()

# Funzione per determinare il genere di un nome
def gender_name(name):
    # Inizializza il dataset dei nomi
    nd = NameDataset()
    # Cerca il nome nel dataset
    name_info = nd.search(name)
    if name_info and 'first_name' in name_info and name_info['first_name']:
        # Ottieni le informazioni sul genere
        gender_info = name_info['first_name'].get('gender')
        if gender_info:
            # Estrai il genere più probabile
            most_probable_gender = max(gender_info, key=gender_info.get)
            return most_probable_gender
    # Se non ci sono informazioni sul genere, restituisci 'unknown'
    return None

# Funzione per estrarre i personaggi comuni tra scena e ruoli
def estrai_personaggi_comuni(scena, ruoli, parole_chiave, ):
    # Dizionario per mappare le parole pulite alle loro versioni originali
    parole_originali = {}

    # Rimuove la punteggiatura da ogni parola nella scena e costruisce il dizionario
    personaggi_scena = []
    for word in scena.split():
        parola_pulita = word.strip(string.punctuation)
        if parola_pulita.isupper():  # Controlla se la parola è interamente maiuscola
            personaggi_scena.append(parola_pulita.lower())  # Aggiunge la parola in minuscolo alla lista
            parole_originali[parola_pulita.lower()] = parola_pulita  # Mappa la parola in minuscolo alla sua forma originale

    # Converte i ruoli e le parole chiave in minuscolo
    ruoli_set = set(ruolo.lower() for ruolo in ruoli)
    parole_chiave_set = set(parola.lower() for parola in parole_chiave)

    # Trova gli elementi comuni tra i tre insiemi
    personaggi_comuni_set = set()
    for personaggio in personaggi_scena:
        if personaggio in ruoli_set.union(parole_chiave_set):
            personaggi_comuni_set.add(parole_originali[personaggio])

    # Restituisce le parole nel loro formato originale, mantenendo l'ordine originale
    personaggi_comuni = [personaggio for personaggio in parole_originali.values() if personaggio in personaggi_comuni_set]

    return ' '.join(personaggi_comuni)


def estrai_ruoli_comuni(scena, ruoli_cast, parole_chiave_maschi):
    # Rimuove la punteggiatura dalla scena
    scena_pulita = re.sub(r'[{}]'.format(re.escape(string.punctuation)), '', scena)

    # Trova le parole con iniziale maiuscola e le abbreviazioni
    parole_iniziali_maiuscole = re.findall(r'\b[A-Z][a-z]*\.?\b', scena_pulita)

    # Converte i ruoli_cast e le parole chiave in un set per la corrispondenza più efficiente
    ruoli_cast_set = set(ruolo.lower() for ruolo in ruoli_cast)
    parole_chiave_set = set(parola.lower() for parola in parole_chiave_maschi)

    # Trova le parole comuni tra le parole iniziali maiuscole e i ruoli_cast
    ruoli_comuni_set = set()
    for parola in parole_iniziali_maiuscole:
        parola_minuscola = parola.lower()
        if parola_minuscola in ruoli_cast_set:
            ruoli_comuni_set.add(parola)

    # Trova le parole chiave direttamente nella scena
    parole_chiave_trovate = set()
    parole_nella_scena = scena_pulita.lower().split()
    for parola in parole_nella_scena:
        if parola in parole_chiave_set:
            parole_chiave_trovate.add(parola)

    # Restituisce i ruoli comuni e le parole chiave trovate come stringa separata da spazi
    return ' '.join(ruoli_comuni_set) + ' ' + ' '.join(parole_chiave_trovate)



# Funzione per aggiornare la colonna count_female nella tabella SCRIPT


def update_script_counts(parole_chiave, parole_chiave_maschi, film_id):

    with engine.begin() as conn:
        # Seleziona i ruoli di tutti i personaggi dalla tabella CAST per il film specificato
        cast_roles = conn.execute(text('''
            SELECT ruolo, LOWER(gender)
            FROM CAST
            WHERE film_id = :film_id
        '''), {'film_id': film_id}).fetchall()

        cast_roles_map = {'male': set(), 'female': set()}
        for role, gender in cast_roles:
            if gender == 'male':
                cast_roles_map['male'].add(role.lower())
            elif gender == 'female':
                cast_roles_map['female'].add(role.lower())

        # Converti le parole chiave in minuscolo
        parole_chiave_set = set(parola.lower() for parola in parole_chiave)
        parole_chiave_maschi_set = set(parola.lower() for parola in parole_chiave_maschi)

        # Rimuovi le parole chiave dalle liste dei ruoli del cast
        cast_roles_map['male'] -= parole_chiave_set
        cast_roles_map['male'] -= parole_chiave_maschi_set
        cast_roles_map['female'] -= parole_chiave_set
        cast_roles_map['female'] -= parole_chiave_maschi_set

        scripts = conn.execute(text('''
            SELECT film_id, scene_id, personaggi
            FROM SCRIPT
            WHERE film_id = :film_id
        '''), {'film_id': film_id}).fetchall()

        # Calcola il conteggio degli elementi comuni e aggiorna la tabella SCRIPT
        for script in scripts:
            personaggi = script[2].lower().split()
            common_count = sum(1 for personaggio in personaggi if personaggio in cast_roles_map['female'])
            keyword_count = sum(1 for personaggio in personaggi if personaggio in parole_chiave_set)
            male_count = sum(1 for personaggio in personaggi if personaggio in cast_roles_map['male'])
            keyword_male_count = sum(1 for personaggio in personaggi if personaggio in parole_chiave_maschi_set)
            total_count = common_count + keyword_count
            total_male_count = male_count + keyword_male_count
            conn.execute(text('''
                UPDATE SCRIPT
                SET count_female = :count_female,
                    count_male = :count_male
                WHERE film_id = :film_id AND scene_id = :scene_id
            '''), {'count_female': total_count, 'count_male': total_male_count, 'film_id': script[0], 'scene_id': script[1]})




def update_script_male_nom_counts(parole_chiave_maschi):

    parole_chiave_maschi_set = set(parola.lower() for parola in parole_chiave_maschi)

    with engine.begin() as conn:
        # Seleziona le righe dalla tabella SCRIPT
        scripts = conn.execute(text('''
            SELECT film_id, scene_id, nom
            FROM SCRIPT
        ''')).fetchall()

        for script in scripts:
            count_male_nom = 0
            if script[2]:  # Verifica se la colonna nom non è vuota
                nom_names = script[2].split()  # Dividi la stringa in parole
                for name in nom_names:
                    # Verifica se il nome è presente tra le parole chiave maschili
                    if name.lower() in parole_chiave_maschi_set:
                        count_male_nom += 1
                    else:
                        # Se non è tra le parole chiave, cerca nella tabella CAST per ruoli maschili
                        result = conn.execute(text('''
                            SELECT 1
                            FROM CAST
                            WHERE film_id = :film_id
                                AND LOWER(gender) = 'male'
                                AND LOWER(ruolo) = :ruolo
                        '''), {'film_id': script[0], 'ruolo': name.lower()}).fetchone()
                        if result:
                            count_male_nom += 1

            # Aggiorna la colonna count_male_nom nella riga corrente
            conn.execute(text('''
                UPDATE SCRIPT
                SET count_male_nom = :count_male_nom
                WHERE film_id = :film_id AND scene_id = :scene_id
            '''), {'count_male_nom': count_male_nom, 'film_id': script[0], 'scene_id': script[1]})

# Funzione principale
def main():
    # Lista di film con titoli e ID IMDb
    films = [
        {"titolo": "Rocky", "imdb_id": "tt0075148", "anno": 1976},
        {"titolo": "Blade Runner","imdb_id": "tt0083658", "anno":1982 },
        {"titolo": "Dead Poets Society", "imdb_id": "tt0097165", "anno": 1989},
        {"titolo": "Fargo", "imdb_id": "tt0116282", "anno": 1996},
        {"titolo": "Good Will Hunting", "imdb_id": "tt0119217", "anno": 1997},
        {"titolo": "Truman Show, The", "imdb_id": "tt0120382", "anno": 1998},
        {"titolo": "American Beauty", "imdb_id": "tt0169547", "anno": 1999},
        {"titolo": "Gladiator", "imdb_id": "tt0172495", "anno": 2000},
        {"titolo": "Memento", "imdb_id": "tt0209144", "anno": 2000},
        {"titolo": "American Psycho", "imdb_id": "tt0144084", "anno": 2000},
        {"titolo": "Big Fish", "imdb_id": "tt0319061", "anno": 2003},
        {"titolo": "Eternal Sunshine of the Spotless Mind", "imdb_id": "tt0338013", "anno": 2004},
        {"titolo": "Devil Wears Prada, The", "imdb_id": "tt0458352", "anno": 2006},
        {"titolo": "No Country for Old Men", "imdb_id": "tt0477348", "anno": 2007},
        {"titolo": "Anna Karenina", "imdb_id": "tt1781769", "anno": 2012},
        {"titolo": "12 Years a Slave", "imdb_id": "tt2024544", "anno": 2013},
        {"titolo": "Great Gatsby, The", "imdb_id": "tt1343092", "anno": 2013},
        {"titolo": "Interstellar", "imdb_id": "tt0816692", "anno": 2014},
        {"titolo": "American Sniper", "imdb_id": "tt2179136", "anno": 2014},
        {"titolo": "La La Land", "imdb_id": "tt3783958", "anno": 2016},
    ]

    parole_chiave = [
        "LADY", "WOMAN", "MOM", "Mother","AUNT", "WIFE", "GIRLFRIEND", "MOTHER","GRANDMOTHER", "GRANDMA", "FEMALE", "GIRL", "ACTRESS", "MISS", "MS.", "MRS","ASSISTANT", "NURSE","princess","Queen"
    ]
    parole_chiave_maschi = [
        "Sir", "Man", "Dad", "Uncle", "Husband", "Boy", "Father","Grandad", "Grandfather", "Male","Prince", "Mr", "King"
    ]

    for film_id, film in enumerate(films, start=1):
        titolo_film = film["titolo"]
        imdb_id = film["imdb_id"]
        anno = film["anno"]

        # Scarica il cast da IMDb
        cast_list = scarica_cast_da_imdb(imdb_id)

        # Inserimento dati nella tabella CAST se non esistono già nelle tabelle FEMALE e MALE
        with engine.begin() as conn:
            for actor in cast_list:
                first_name = actor['name'].split(' ', 1)[0]
                most_probable_gender = gender_name(first_name)
                if most_probable_gender is None:
                # Se il genere è sconosciuto, passa alla prossima iterazione del ciclo
                    continue
                print(f"Determinato gender per {first_name} ({actor['name']}): {most_probable_gender}")
                cast_data = {
                    'film_id': film_id,
                    'nome': actor['name'],
                    'ruolo': pulisci_ruolo(actor['role']),
                    'gender': most_probable_gender,
                }
                insert_data(cast_data, 'CAST')

        # Scarica e divide lo script da IMSDb
        scene_divise = scarica_e_dividi_script_da_imsdb(titolo_film)

        # Estrai i ruoli da CAST per i personaggi delle scene
        ruoli_cast = [pulisci_ruolo(actor['role']) for actor in cast_list]

        if scene_divise:
            # Svuota la lista dei ruoli del cast e riempila con i nuovi ruoli
            ruoli_cast.clear()
            ruoli_cast.extend(pulisci_ruolo(actor['role']) for actor in cast_list)
            print(ruoli_cast)
            # Inserisci le scene nel database e calcola count_male, count_female e count_nom
            for scene_id, scene in enumerate(scene_divise, start=1):
                place = scene['place']
                cleaned_scene = pulisci_scena(scene['scena'])
                ruoli_comuni = estrai_ruoli_comuni(scene['scena'], ruoli_cast, parole_chiave_maschi)
                personaggi_comuni = estrai_personaggi_comuni(scene['scena'], ruoli_cast, parole_chiave)

                # Calcola count_female e count_male_nom
                count_female = sum(1 for personaggio in personaggi_comuni.split() if personaggio in parole_chiave)

                count_male_nom = sum(1 for nome in ruoli_comuni.split() if nome in parole_chiave_maschi)

                scene_data = {
                    'film_id': film_id,
                    'scene_id': scene_id,
                    'place': place,
                    'scena': cleaned_scene,
                    'personaggi': personaggi_comuni,
                    'count_female': count_female,
                    'count_male': 0,  # Calcolato in update_script_counts
                    'nom': ruoli_comuni,
                    'count_male_nom': count_male_nom,
                }
                insert_data(scene_data, 'SCRIPT')

            print(f"Scene del film {titolo_film} inserite nel database.")

        # Inserimento dati nella tabella MOVIE
        movie_data = {'film_id': film_id, 'titolo': titolo_film, 'anno': anno}
        insert_data(movie_data, 'MOVIE')

        # Aggiorna la colonna count_female nella tabella SCRIPT
        update_script_counts(parole_chiave, parole_chiave_maschi, film_id)
        update_script_male_nom_counts(parole_chiave_maschi)

if __name__ == "__main__":
    main()
# Out:
# Determinato gender per Sylvester (Sylvester Stallone): Male
# Determinato gender per Talia (Talia Shire): Female
# Determinato gender per Burt (Burt Young): Male
# Determinato gender per Carl (Carl Weathers): Male
# Determinato gender per Burgess (Burgess Meredith): Male
# Determinato gender per Thayer (Thayer David): Male
# Determinato gender per Joe (Joe Spinell): Male
# Determinato gender per Jimmy (Jimmy Gambina): Male
# Determinato gender per Bill (Bill Baldwin): Male
# Determinato gender per Al (Al Silvani): Male
# Determinato gender per George (George Memmoli): Male
# Determinato gender per Jodi (Jodi Letizia): Female
# Determinato gender per Diana (Diana Lewis): Female
# Determinato gender per Stan (Stan Shaw): Male
# Determinato gender per Don (Don Sherman): Male
# Determinato gender per Billy (Billy Sands): Male
# Determinato gender per Shirley (Shirley O'Hara): Female
# Determinato gender per Kathleen (Kathleen Parker): Female
# Determinato gender per Frank (Frank Stallone): Male
# Determinato gender per Lloyd (Lloyd Kaufman): Male
# Determinato gender per Jane (Jane Marla Robbins): Female
# Determinato gender per Jack (Jack Hollander): Male
# Determinato gender per Joe (Joe Sorbello): Male
# Determinato gender per Christopher (Christopher Avildsen): Male
# Determinato gender per Lou (Lou Fillipo): Female
# Determinato gender per Paris (Paris Eagle): Female
# Determinato gender per Frank (Frank Stallone): Male
# Determinato gender per Joe (Joe Frazier): Male
# Determinato gender per Don (Don Cannon): Male
# Determinato gender per Bobby (Bobby Cassidy): Male
# Determinato gender per Randy (Randy De La o): Male
# Determinato gender per Daniel (Daniel King): Male
# Determinato gender per Jeri (Jeri McBride): Female
# Determinato gender per Lavelle (Lavelle Roby): Male
# Determinato gender per Chino (Chino 'Fats' Williams): Male
# ['Rocky', 'Adrian', 'Paulie', 'Apollo', 'Mickey', 'Jergens', 'Gazzo', 'Mike', 'Fight', 'Cut', 'Ice', 'Marie', 'TV', 'Dipper', 'Bartender', 'Club', 'Apollos', 'Secretary', 'Paulies', 'Timekeeper', 'Drunk', 'Owner', 'Fats', 'Bodyguard', 'Chiptooth', 'Championship', 'Fighter', 'Streetcorner', 'Joe', 'Dog', 'Radio', 'Ringside', 'Boxer', 'Big', 'Tony', 'Mary', 'Man']
# Scene del film Rocky inserite nel database.
# Determinato gender per Harrison (Harrison Ford): Male
# Determinato gender per Sean (Sean Young): Male
# Determinato gender per Rutger (Rutger Hauer): Male
# Determinato gender per Edward (Edward James Olmos): Male
# Determinato gender per Daryl (Daryl Hannah): Male
# Determinato gender per William (William Sanderson): Male
# Determinato gender per Brion (Brion James): Male
# Determinato gender per Joe (Joe Turkel): Male
# Determinato gender per Joanna (Joanna Cassidy): Female
# Determinato gender per James (James Hong): Male
# Determinato gender per Morgan (Morgan Paull): Male
# Determinato gender per Kevin (Kevin Thompson): Male
# Determinato gender per John (John Edward Allen): Male
# Determinato gender per Hy (Hy Pyke): Male
# Determinato gender per Kimiko (Kimiko Hiroshige): Female
# Determinato gender per Bob (Bob Okazaki): Male
# Determinato gender per Carolyn (Carolyn DeMirjian): Female
# Determinato gender per Ben (Ben Astar): Male
# Determinato gender per Tony (Tony Cox): Male
# Determinato gender per Leo (Leo Gorcey Jr.): Male
# Determinato gender per Sharon (Sharon Hesky): Female
# Determinato gender per Sharon (Sharon Miller): Female
# Determinato gender per Alexis (Alexis Rhee): Male
# Determinato gender per Marc (Marc Smith): Male
# ['Deckard', 'Rachael', 'Batty', 'Gaff', 'Bryant', 'Pris', 'Sebastian', 'Leon', 'Tyrell', 'Zhora', 'Chew', 'Holden', 'Bear', 'Kaiser', 'Taffey', 'Cambodian', 'Sushi', 'Saleslady', 'Abdul', 'Street', 'Louie', 'Bar', 'Headturning', 'Geisha', 'OffWorld']
# Scene del film Blade Runner inserite nel database.
# Determinato gender per Robin (Robin Williams): Male
# Determinato gender per Robert (Robert Sean Leonard): Male
# Determinato gender per Ethan (Ethan Hawke): Male
# Determinato gender per Josh (Josh Charles): Male
# Determinato gender per Gale (Gale Hansen): Female
# Determinato gender per Dylan (Dylan Kussman): Male
# Determinato gender per James (James Waterston): Male
# Determinato gender per Norman (Norman Lloyd): Male
# Determinato gender per Carla (Carla Belver): Female
# Determinato gender per Leon (Leon Pownall): Male
# Determinato gender per George (George Martin): Male
# Determinato gender per Joe (Joe Aufiery): Male
# Determinato gender per Matt (Matt Carey): Male
# Determinato gender per Kevin (Kevin Cooney): Male
# Determinato gender per Lara (Lara Flynn Boyle): Female
# Determinato gender per Colin (Colin Irving): Male
# Determinato gender per Alexandra (Alexandra Powers): Female
# Determinato gender per Welker (Welker White): Male
# Determinato gender per Steve (Steve Mathios): Male
# Determinato gender per Alan (Alan Pottinger): Male
# Determinato gender per Pamela (Pamela Burrell): Female
# Determinato gender per Allison (Allison Hedges): Female
# Determinato gender per Christine (Christine D'Ercole): Female
# Determinato gender per John (John Martin Bradley): Male
# Determinato gender per Kurt (Kurt Leitner): Male
# Determinato gender per Richard (Richard Stites): Male
# Determinato gender per James (James J. Christy): Male
# Determinato gender per Catherine (Catherine Soles): Female
# Determinato gender per Hoover (Hoover Sutton): Male
# Determinato gender per James (James Donnell Quinn): Male
# Determinato gender per Ashton (Ashton W. Richards): Male
# Determinato gender per Robert (Robert Gleason): Male
# Determinato gender per Bill (Bill Rowe): Male
# Determinato gender per Robert (Robert J. Zigler III): Male
# Determinato gender per Keith (Keith Snyder): Male
# Determinato gender per Nicholas (Nicholas K. Gilhool): Male
# Determinato gender per Jonas (Jonas Stiklorius): Male
# Determinato gender per Craig (Craig Johnson): Male
# Determinato gender per Chris (Chris Hull): Male
# Determinato gender per Jason (Jason Woody): Male
# Determinato gender per Sam (Sam Stegeman): Male
# Determinato gender per Andrew (Andrew Hill): Male
# Determinato gender per Serena (Serena Ebhardt): Female
# Determinato gender per Newton (Newton Gilchrist): Male
# Determinato gender per Barry (Barry Godin): Male
# Determinato gender per Kate (Kate Kearney-Patch): Female
# Determinato gender per Stephen (Stephen Podolak): Male
# Determinato gender per Jeffrey (Jeffrey Santoro): Male
# ['John', 'Neil', 'Todd', 'Knox', 'Charlie', 'Richard', 'Steven', 'Gerard', 'Mr', 'Mrs', 'McAllister', 'Dr', 'Chemistry', 'Hopkins', 'Joe', 'Ginny', 'Chet', 'Chris', 'Gloria', 'Tina', 'Steve', 'Bubba', 'Directing', 'ActorFairy', 'Titania', 'Bagpiper', 'Lester', 'Stick', 'Spaz', 'Stage', 'Welton', 'Procession', 'Phys', 'Father', 'Dormitory', 'Beans', 'Russell', 'Shroom', 'Jonas', 'Dewey', 'Ace', 'Woodsie', 'Sam', 'Senior', 'Midsummer', 'Teacher', 'Language', 'Mother', 'Theater', 'Public']
# Scene del film Dead Poets Society inserite nel database.
# Determinato gender per William (William H. Macy): Male
# Determinato gender per Steve (Steve Buscemi): Male
# Determinato gender per Peter (Peter Stormare): Male
# Determinato gender per Kristin (Kristin Rudrüd): Female
# Determinato gender per Tony (Tony Denman): Male
# Determinato gender per Gary (Gary Houston): Male
# Determinato gender per Kurt (Kurt Schweickhardt): Male
# Determinato gender per Larissa (Larissa Kokernot): Female
# Determinato gender per Steve (Steve Reevis): Male
# Determinato gender per Warren (Warren Keith): Male
# Determinato gender per Steve (Steve Edelman): Male
# Determinato gender per Larry (Larry Brandenburg): Male
# Determinato gender per James (James Gaulke): Male
# Determinato gender per Frances (Frances McDormand): Female
# Determinato gender per John (John Carroll Lynch): Male
# Determinato gender per Bruce (Bruce Bohne): Male
# Determinato gender per Petra (Petra Boden): Female
# Determinato gender per Steve (Steve Park): Male
# Determinato gender per Wayne (Wayne A. Evenson): Male
# Determinato gender per Cliff (Cliff Rakerd): Male
# Determinato gender per Jessica (Jessica Shepherd): Female
# Determinato gender per Peter (Peter Schmitz): Male
# Determinato gender per Steven (Steven I. Schafer): Male
# Determinato gender per Michelle (Michelle Hutchison): Female
# Determinato gender per David (David S. Lomax): Male
# Determinato gender per José (José Feliciano): Male
# Determinato gender per Bix (Bix Skahill): Male
# Determinato gender per Bain (Bain Boehlke): Male
# Determinato gender per Rose (Rose Stockton): Female
# Determinato gender per Robert (Robert Ozasky): Male
# Determinato gender per Don (Don Wescott): Male
# Determinato gender per Bruce (Bruce Campbell): Male
# Determinato gender per Clifford (Clifford Nelson): Male
# Determinato gender per Lori (Lori J. Ness): Female
# ['Jerry', 'Carl', 'Gaear', 'Jean', 'Wade', 'Scotty', 'Irate', 'Car', 'Hooker', 'Shep', 'Reilly', 'Morning', 'Stan', 'State', 'Victim', 'Marge', 'Norm', 'Lou', 'Cashier', 'Mike', 'Customeras', 'Officer', 'Hotel', 'Airport', 'Mechanicas', 'Escortas', 'Man', 'José', 'Night', 'Mr', 'Valerievoice', 'Bismarck', 'Bark', 'Soap', 'Heavyset', 'Women']
# Scene del film Fargo inserite nel database.
# Determinato gender per Matt (Matt Damon): Male
# Determinato gender per Ben (Ben Affleck): Male
# Determinato gender per Stellan (Stellan Skarsgård): Male
# Determinato gender per John (John Mighton): Male
# Determinato gender per Rachel (Rachel Majorowski): Female
# Determinato gender per Colleen (Colleen McCauley): Female
# Determinato gender per Casey (Casey Affleck): Male
# Determinato gender per Cole (Cole Hauser): Male
# Determinato gender per Matt (Matt Mercier): Male
# Determinato gender per Alison (Alison Folland): Female
# Determinato gender per Shannon (Shannon Egleson): Female
# Determinato gender per Rob (Rob Lyons): Male
# Determinato gender per Minnie (Minnie Driver): Female
# Determinato gender per Jennifer (Jennifer Deathe): Female
# Determinato gender per Scott (Scott William Winters): Male
# Determinato gender per Philip (Philip Williams): Male
# Determinato gender per Patrick (Patrick O'Donnell): Male
# Determinato gender per Kevin (Kevin Rushton): Male
# Determinato gender per Jimmy (Jimmy Flynn): Male
# Determinato gender per Joe (Joe Cannon): Male
# Determinato gender per Ann (Ann Matacunas): Female
# Determinato gender per George (George Plimpton): Male
# Determinato gender per Francesco (Francesco Clemente): Male
# Determinato gender per Robin (Robin Williams): Male
# Determinato gender per Jessica (Jessica Morton): Female
# Determinato gender per Libby (Libby Geller): Female
# Determinato gender per Richard (Richard Fitzpatrick): Male
# Determinato gender per Frank (Frank Nakashima): Male
# Determinato gender per Bruce (Bruce Hunter): Male
# Determinato gender per James (James Allodi): Male
# Determinato gender per Michael (Michael Arthur): Male
# Determinato gender per Steve (Steve Bertorelli): Male
# Determinato gender per Nancy (Nancy Carlsson-Paige): Female
# Determinato gender per Kent (Kent Damon): Male
# Determinato gender per Robert (Robert Harrell): Male
# Determinato gender per Elisabeth (Elisabeth Anne Hughes): Female
# ['Will', 'Chuckie', 'Lambeau', 'Tom', 'Krystyn', 'Cathy', 'Morgan', 'Billy', 'Barbershop', 'MIT', 'Girl', 'Carmine', 'Skylar', 'Lydia', 'Clark', 'Head', 'Assistant', 'Courtroom', 'Judge', 'Prosecutor', 'Court', 'Psychologist', 'Hypnotist', 'Sean', 'Bunker', 'Toy', 'Timmy', 'Executive', 'NSA', 'Security', 'Reunion', 'Party', 'Harvard', 'Chess', 'Race', 'Reception']
# Scene del film Good Will Hunting inserite nel database.
# Determinato gender per Jim (Jim Carrey): Male
# Determinato gender per Laura (Laura Linney): Female
# Determinato gender per Noah (Noah Emmerich): Male
# Determinato gender per Natascha (Natascha McElhone): Female
# Determinato gender per Holland (Holland Taylor): Male
# Determinato gender per Blair (Blair Slater): Male
# Determinato gender per Peter (Peter Krause): Male
# Determinato gender per Heidi (Heidi Schanz): Female
# Determinato gender per Ron (Ron Taylor): Male
# Determinato gender per Don (Don Taylor): Male
# Determinato gender per Ted (Ted Raymond): Male
# Determinato gender per Judy (Judy Clayton): Female
# Determinato gender per Muriel (Muriel Moore): Female
# Determinato gender per Mal (Mal Jones): Male
# Determinato gender per Judson (Judson Vaughn): Male
# Determinato gender per Earl (Earl Hilliard Jr.): Male
# Determinato gender per David (David Andrew Nash): Male
# Determinato gender per Savannah (Savannah Swafford): Female
# Determinato gender per Antoni (Antoni Corone): Male
# Determinato gender per John (John Roselius): Male
# Determinato gender per Marcia (Marcia DeBonis): Female
# Determinato gender per Sam (Sam Kitchin): Male
# Determinato gender per Sebastian (Sebastian Youngblood): Male
# Determinato gender per Dave (Dave Corey): Male
# Determinato gender per Mark (Mark Alan Gillott): Male
# Determinato gender per Daryl (Daryl Davis): Male
# Determinato gender per Joseph (Joseph Lucus): Male
# Determinato gender per Logan (Logan Kirksey): Male
# Determinato gender per Ed (Ed Harris): Male
# Determinato gender per Paul (Paul Giamatti): Male
# Determinato gender per Harry (Harry Shearer): Male
# Determinato gender per Una (Una Damon): Female
# Determinato gender per Philip (Philip Baker Hall): Male
# Determinato gender per Philip (Philip Glass): Male
# Determinato gender per Joe (Joe Minjares): Male
# Determinato gender per Dona (Dona Hardy): Female
# Determinato gender per Joel (Joel McKinnon Miller): Male
# Determinato gender per Susan (Susan Angelo): Female
# Determinato gender per Carly (Carly Smiga): Female
# Determinato gender per Yuji (Yuji Okumoto): Male
# Determinato gender per Jake (Jake Eberle): Male
# Determinato gender per Melissa (Melissa Fitzgerald): Female
# Determinato gender per Marc (Marc Macaulay): Male
# Determinato gender per Courtney (Courtney Pakiz): Female
# Determinato gender per Kevin (Kevin D. Ross): Male
# Determinato gender per Michael (Michael Satterfield): Male
# Determinato gender per Devin (Devin Schumacher): Male
# ['Truman', 'Meryl', 'Marlon', 'LaurenSylvia', 'Trumans', 'Young', 'Lawrence', 'Vivien', 'Ron', 'Don', 'Spencer', 'Travel', 'Teacher', 'News', 'Insurance', 'Ferry', 'Bus', 'Little', 'Security', 'Man', 'Nurse', 'Surgeon', 'Orderly', 'Hospital', 'Policeman', 'Couple', 'Production', 'Ticket', 'TV', 'Christof', 'Control', 'Mike', 'Chloe', 'Network', 'Keyboard', 'Bar', 'Bartender', 'Senior', 'Garage', 'Mother', 'Daughter', 'Japanese', 'Classical', 'Girl', 'Citizen', 'Assistant', 'German', 'Talk', 'Station', 'Prom', 'Boy']
# Scene del film Truman Show, The inserite nel database.
# Determinato gender per Kevin (Kevin Spacey): Male
# Determinato gender per Annette (Annette Bening): Female
# Determinato gender per Thora (Thora Birch): Female
# Determinato gender per Wes (Wes Bentley): Male
# Determinato gender per Mena (Mena Suvari): Female
# Determinato gender per Peter (Peter Gallagher): Male
# Determinato gender per Allison (Allison Janney): Female
# Determinato gender per Chris (Chris Cooper): Male
# Determinato gender per Scott (Scott Bakula): Male
# Determinato gender per Barry (Barry Del Sherman): Male
# Determinato gender per Ara (Ara Celi): Female
# Determinato gender per Alison (Alison Faulk): Female
# Determinato gender per Heather (Heather Joy Sher): Female
# Determinato gender per Amber (Amber Smith): Female
# Determinato gender per Joel (Joel McCrary): Male
# Determinato gender per Marissa (Marissa Jaret Winokur): Female
# Determinato gender per Matthew (Matthew Kimbrough): Male
# Determinato gender per Erin (Erin Cathryn Strubbe): Female
# Determinato gender per David (David C. Fisher): Male
# Determinato gender per Tom (Tom Miller): Male
# Determinato gender per Ronald (Ronald Reagan): Male
# ['Lester', 'Carolyn', 'Jane', 'Ricky', 'Angela', 'Buddy', 'Barbara', 'Colonel', 'Jim', 'Brad', 'Sale', 'Spartanette', 'Playground', 'Christy', 'Catering', 'Mr', 'Firing', 'Young', 'Wedding', 'Advertising', 'President']
# Scene del film American Beauty inserite nel database.
# Determinato gender per Russell (Russell Crowe): Male
# Determinato gender per Joaquin (Joaquin Phoenix): Male
# Determinato gender per Connie (Connie Nielsen): Female
# Determinato gender per Oliver (Oliver Reed): Male
# Determinato gender per Richard (Richard Harris): Male
# Determinato gender per Derek (Derek Jacobi): Male
# Determinato gender per David (David Schofield): Male
# Determinato gender per John (John Shrapnel): Male
# Determinato gender per Tomas (Tomas Arana): Male
# Determinato gender per Ralf (Ralf Moeller): Male
# Determinato gender per Spencer (Spencer Treat Clark): Male
# Determinato gender per David (David Hemmings): Male
# Determinato gender per Tommy (Tommy Flanagan): Male
# Determinato gender per Sven-Ole (Sven-Ole Thorsen): Male
# Determinato gender per Omid (Omid Djalili): Male
# Determinato gender per Nicholas (Nicholas McGaughey): Male
# Determinato gender per Chris (Chris Kell): Male
# Determinato gender per Tony (Tony Curran): Male
# Determinato gender per John (John Quinn): Male
# Determinato gender per David (David Bailie): Male
# Determinato gender per Chick (Chick Allan): Male
# Determinato gender per David (David J. Nicholls): Male
# Determinato gender per Al (Al Ashton): Male
# Determinato gender per Billy (Billy Dowd): Male
# Determinato gender per Allan (Allan Corduner): Male
# Determinato gender per Said (Said Amel): Male
# Determinato gender per Adam (Adam Levy): Male
# Determinato gender per Paul (Paul Bateman): Male
# Determinato gender per Nick (Nick Beardshaw): Male
# Determinato gender per Corey (Corey Booth): Male
# Determinato gender per Peter (Peter Francis-Wemyss): Male
# Determinato gender per Kjeld (Kjeld Gogosha-Clark): Male
# Determinato gender per Cara (Cara Higgins): Female
# Determinato gender per Earl (Earl Hundt): Male
# Determinato gender per Antonio (Antonio Meitin): Male
# Determinato gender per Norman (Norman Campbell Rees): Male
# Determinato gender per Paul (Paul Sacks): Male
# Determinato gender per Christian (Christian Simpson): Male
# Determinato gender per Brian (Brian Smyj): Male
# Determinato gender per Paul (Paul Woodadge): Male
# Determinato gender per Michael (Michael Yale): Male
# ['Maximus', 'Commodus', 'Lucilla', 'Proximo', 'Marcus', 'Gracchus', 'Juba', 'Falco', 'Gaius', 'Quintus', 'Hagen', 'Lucius', 'Cassius', 'Cicero', 'Tigris', 'Slave', 'Praetorian', 'Scribe', 'Assassin', 'Valerius', 'Engineer', 'German', 'Giant', 'Rome', 'Narrator', 'Trainer', 'Proximos', 'Officer', 'Germanic', 'Roman', 'Yeroc', 'Barbarian', 'CGI', 'Vestal', 'City', 'Battlefield', 'Sedan', 'Catapult', 'Chief', 'Coliseum', 'Germanian', 'Citizen']
# Scene del film Gladiator inserite nel database.
# Determinato gender per Guy (Guy Pearce): Male
# Determinato gender per Carrie-Anne (Carrie-Anne Moss): Female
# Determinato gender per Joe (Joe Pantoliano): Male
# Determinato gender per Mark (Mark Boone Junior): Male
# Determinato gender per Russ (Russ Fega): Male
# Determinato gender per Jorja (Jorja Fox): Female
# Determinato gender per Stephen (Stephen Tobolowsky): Male
# Determinato gender per Harriet (Harriet Sansom Harris): Female
# Determinato gender per Thomas (Thomas Lennon): Male
# Determinato gender per Callum (Callum Keith Rennie): Male
# Determinato gender per Kimberly (Kimberly Campbell): Female
# Determinato gender per Marianne (Marianne Muellerleile): Female
# Determinato gender per Larry (Larry Holden): Male
# Determinato gender per Stephanie (Stephanie Searson): Female
# ['Leonard', 'Natalie', 'Teddy', 'Burt', 'Waiter', 'Leonards', 'Sammy', 'Mrs', 'Doctor', 'Dodd', 'Blonde', 'Tattooist', 'Jimmy', 'Motel', 'Jimmys']
# Scene del film Memento inserite nel database.
# Determinato gender per Christian (Christian Bale): Male
# Determinato gender per Justin (Justin Theroux): Male
# Determinato gender per Josh (Josh Lucas): Male
# Determinato gender per Bill (Bill Sage): Male
# Determinato gender per Chloë (Chloë Sevigny): Female
# Determinato gender per Reese (Reese Witherspoon): Male
# Determinato gender per Samantha (Samantha Mathis): Female
# Determinato gender per Matt (Matt Ross): Male
# Determinato gender per Jared (Jared Leto): Male
# Determinato gender per Willem (Willem Dafoe): Male
# Determinato gender per Cara (Cara Seymour): Female
# Determinato gender per Guinevere (Guinevere Turner): Female
# Determinato gender per Stephen (Stephen Bogaert): Male
# Determinato gender per Monika (Monika Meier): Female
# Determinato gender per Reg (Reg E. Cathey): Male
# Determinato gender per Blair (Blair Williams): Male
# Determinato gender per Marie (Marie Dame): Female
# Determinato gender per Kelley (Kelley Harron): Female
# Determinato gender per Patricia (Patricia Gage): Female
# Determinato gender per Krista (Krista Sutton): Female
# Determinato gender per Landy (Landy Cannon): Female
# Determinato gender per Park (Park Bench): Female
# Determinato gender per Catherine (Catherine Black): Female
# Determinato gender per Margaret (Margaret Ma): Female
# Determinato gender per Peter (Peter Tufford Kennedy): Male
# Determinato gender per Mark (Mark Pawson): Male
# Determinato gender per Jessica (Jessica Lau): Female
# Determinato gender per Lilette (Lilette Wiens): Female
# Determinato gender per Charlotte (Charlotte Hunter): Female
# Determinato gender per Kiki (Kiki Buttignol): Female
# Determinato gender per Joyce (Joyce R. Korbin): Female
# Determinato gender per Bryan (Bryan Renfro): Male
# Determinato gender per Christina (Christina McKay): Female
# Determinato gender per Anthony (Anthony Lemke): Male
# Determinato gender per Connie (Connie Chen): Female
# Determinato gender per Marilyn (Marilyn Burns): Female
# Determinato gender per Joseph (Joseph Oliveira): Male
# Determinato gender per Leanne (Leanne Poirier Greenfield): Female
# Determinato gender per Ronald (Ronald Reagan): Male
# Determinato gender per Somaya (Somaya Reece): Female
# Determinato gender per Kate (Kate Steen): Female
# Determinato gender per Dave (Dave Thompson): Male
# ['Patrick', 'Timothy', 'Craig', 'David', 'Jean', 'Evelyn', 'Courtney', 'Luis', 'Paul', 'Donald', 'Christie', 'Elizabeth', 'Harold', 'Daisy', 'Homeless', 'Waiter', 'Victoria', 'Bargirl', 'Mrs', 'Sabrina', 'Man', 'Stash', 'Vanden', 'Dry', 'Hamiltonas', 'Humphrey', 'Facialist', 'Maitre', 'Libby', 'Caron', 'Woman', 'Night', 'Young', 'Marcus', 'Gwendolyn', 'Sally', 'Restaurant', 'Party', 'Selfarchive', 'Bar', 'Pierce', 'Tattletale']
# Scene del film American Psycho inserite nel database.
# Determinato gender per Ewan (Ewan McGregor): Male
# Determinato gender per Billy (Billy Crudup): Male
# Determinato gender per Jessica (Jessica Lange): Female
# Determinato gender per Helena (Helena Bonham Carter): Female
# Determinato gender per Robert (Robert Guillaume): Male
# Determinato gender per Marion (Marion Cotillard): Female
# Determinato gender per Matthew (Matthew McGrory): Male
# Determinato gender per David (David Denman): Male
# Determinato gender per Missi (Missi Pyle): Female
# Determinato gender per Ada (Ada Tai): Female
# Determinato gender per Arlene (Arlene Tai): Female
# Determinato gender per Steve (Steve Buscemi): Male
# Determinato gender per Danny (Danny DeVito): Male
# Determinato gender per Deep (Deep Roy): Male
# Determinato gender per Zac (Zac Gardner): Male
# Determinato gender per Darrell (Darrell Vanterpool): Male
# Determinato gender per Miley (Miley Cyrus): Female
# Determinato gender per Joseph (Joseph Humphrey): Male
# Determinato gender per Morgan (Morgan Grace Jarrett): Male
# Determinato gender per Sallie (Sallie Hedrick): Female
# Determinato gender per Charles (Charles McLawhorn): Male
# Determinato gender per Frank (Frank Hoyt Taylor): Male
# Determinato gender per Billy (Billy Redden): Male
# Determinato gender per James (James DeForest Parker): Male
# Determinato gender per Russell (Russell Hodgkinson): Male
# Determinato gender per Don (Don Young): Male
# Determinato gender per Jayne (Jayne Morgan): Female
# Determinato gender per Zach (Zach Hanner): Male
# Determinato gender per George (George McArthur): Male
# Determinato gender per Jeff (Jeff Campbell): Male
# Determinato gender per Lawrence (Lawrence Sykkmon): Male
# Determinato gender per Bonnie (Bonnie Johnson): Female
# Determinato gender per Howard (Howard Houston Jr.): Male
# Determinato gender per Joanne (Joanne Pankow): Female
# Determinato gender per Jacob (Jacob Radford): Male
# Determinato gender per Cathy (Cathy Berry): Female
# Determinato gender per John (John Fugate): Male
# Determinato gender per Daniel (Daniel Wallace): Male
# Determinato gender per Metz (Metz Duites): Male
# Determinato gender per Vincent (Vincent J. Ybiernas): Male
# Determinato gender per Barry (Barry C. Harvard): Male
# Determinato gender per Edward (Edward Aldag): Male
# Determinato gender per Michael (Michael Garnet Stewart): Male
# Determinato gender per Jake (Jake Brake): Male
# Determinato gender per Bevin (Bevin Kaye): Male
# Determinato gender per Hélène (Hélène Cardona): Female
# Determinato gender per Chris (Chris Cate): Male
# Determinato gender per John (John Collier): Male
# Determinato gender per Derek (Derek Frey): Male
# Determinato gender per Ransom (Ransom Gates): Male
# Determinato gender per Michael (Michael Griffiths): Male
# Determinato gender per Nick (Nick Mielke): Male
# Determinato gender per Priscilla (Priscilla Monnier): Female
# Determinato gender per Darlene (Darlene Moore): Female
# Determinato gender per Gary (Gary Newton): Male
# Determinato gender per Adam (Adam Ragsdale): Male
# Determinato gender per Bruce (Bruce Snowdon): Male
# Determinato gender per Robin (Robin Steele): Male
# ['Edward', 'Will', 'Sandra', 'Jenny', 'Dr', 'Josephine', 'Karl', 'Don', 'Mildred', 'Beamenas', 'Ping', 'Jing', 'Norther', 'Amos', 'Mr', 'Eds', 'Zacky', 'Wilbur', 'Ruthie', 'Little', 'Wills', 'Pretty', 'Mayor', 'Sharecropper', 'Banjo', 'Shotgun', 'Some', 'Shephard', 'Townsperson', 'Cashier', 'Colossus', 'Jump', 'Chinese', 'Teller', 'Piano', 'Heavy', 'Kid', 'Lobster', 'Side', 'Econ', 'Ventriloquist', 'Asian', 'Chicken', 'Municipal', 'Auctioneer', 'Old', 'River', 'Secretaryvoice', 'Spectre', 'Parade', 'Army', 'Big', 'Spontaneous', 'Funeral', 'Spectres', 'County', 'Circus', 'Misshaped', 'Fat', 'College']
# Scene del film Big Fish inserite nel database.
# Determinato gender per Jim (Jim Carrey): Male
# Determinato gender per Kate (Kate Winslet): Female
# Determinato gender per Gerry (Gerry Robert Byrne): Male
# Determinato gender per Elijah (Elijah Wood): Male
# Determinato gender per Thomas (Thomas Jay Ryan): Male
# Determinato gender per Mark (Mark Ruffalo): Male
# Determinato gender per Jane (Jane Adams): Female
# Determinato gender per David (David Cross): Male
# Determinato gender per Kirsten (Kirsten Dunst): Female
# Determinato gender per Tom (Tom Wilkinson): Male
# Determinato gender per Ryan (Ryan Whitney): Male
# Determinato gender per Deirdre (Deirdre O'Connell): Female
# ['Joel', 'Clementine', 'Train', 'Patrick', 'Frank', 'Stan', 'Carrie', 'Rob', 'Mary', 'Dr', 'Young', 'Joels', 'Hollis']
# Scene del film Eternal Sunshine of the Spotless Mind inserite nel database.
# Determinato gender per Meryl (Meryl Streep): Female
# Determinato gender per Anne (Anne Hathaway): Female
# Determinato gender per Emily (Emily Blunt): Female
# Determinato gender per Stanley (Stanley Tucci): Male
# Determinato gender per Simon (Simon Baker): Male
# Determinato gender per Adrian (Adrian Grenier): Male
# Determinato gender per Tracie (Tracie Thoms): Female
# Determinato gender per Rich (Rich Sommer): Male
# Determinato gender per Daniel (Daniel Sunjata): Male
# Determinato gender per David (David Marshall Grant): Male
# Determinato gender per James (James Naughton): Male
# Determinato gender per Tibor (Tibor Feldman): Male
# Determinato gender per Rebecca (Rebecca Mader): Female
# Determinato gender per Jimena (Jimena Hoyos): Female
# Determinato gender per Gisele (Gisele Bündchen): Female
# Determinato gender per George (George C. Wolfe): Male
# Determinato gender per John (John Rothman): Male
# Determinato gender per Stephanie (Stephanie Szostak): Female
# Determinato gender per Colleen (Colleen Dengel): Female
# Determinato gender per Suzanne (Suzanne Dengel): Female
# Determinato gender per Heidi (Heidi Klum): Female
# Determinato gender per Ines (Ines Rivero): Female
# Determinato gender per Robert (Robert Verdi): Male
# Determinato gender per Paul (Paul Keany): Male
# Determinato gender per David (David Callegati): Male
# Determinato gender per Rori (Rori Cannon): Female
# Determinato gender per Stan (Stan Newman): Male
# Determinato gender per James (James Cronin): Male
# Determinato gender per Eric (Eric Seltzer): Male
# Determinato gender per Lindsay (Lindsay Brice): Female
# Determinato gender per John (John Graham): Male
# Determinato gender per Wells (Wells Dixon): Male
# Determinato gender per Mauricio (Mauricio Alexander): Male
# Determinato gender per Ilona (Ilona Alexandra): Female
# Determinato gender per Alexander (Alexander Blaise): Male
# Determinato gender per Scott (Scott Hatfield): Male
# Determinato gender per Julie (Julie Jei): Female
# Determinato gender per Dutch (Dutch Johnson): Male
# Determinato gender per Tim (Tim Krueger): Male
# Determinato gender per Zev (Zev McAllister): Male
# Determinato gender per Laura (Laura McDavid): Female
# Determinato gender per Carrie (Carrie Navarro): Female
# Determinato gender per Darren (Darren Pettis): Male
# Determinato gender per Jennifer (Jennifer Scott): Female
# Determinato gender per Stella (Stella Stark): Female
# ['Miranda', 'Andy', 'Emily', 'Nigel', 'Christian', 'Nate', 'Lily', 'Doug', 'James', 'Richard', 'Stephen', 'Irv', 'Jocelyn', 'Lucia', 'Serena', 'Paul', 'Editor', 'Jacqueline', 'Caroline', 'Cassidy', 'Self', 'Clacker', 'Fashion', 'St', 'Massimoas', 'Girl', 'John', 'Ambassador', 'Roy', 'PR', 'Book', 'Mirandas', 'Lobby', 'Red', 'French', 'Parisian', 'New', 'Gara', 'Black', 'Fund', 'Runway', 'Gala', 'RunwayMagazine', 'Guy', 'Counter', 'Restaurant']
# Scene del film Devil Wears Prada, The inserite nel database.
# Determinato gender per Tommy (Tommy Lee Jones): Male
# Determinato gender per Javier (Javier Bardem): Male
# Determinato gender per Josh (Josh Brolin): Male
# Determinato gender per Woody (Woody Harrelson): Male
# Determinato gender per Kelly (Kelly Macdonald): Female
# Determinato gender per Garret (Garret Dillahunt): Male
# Determinato gender per Tess (Tess Harper): Female
# Determinato gender per Barry (Barry Corbin): Male
# Determinato gender per Stephen (Stephen Root): Male
# Determinato gender per Rodger (Rodger Boyce): Male
# Determinato gender per Ana (Ana Reeder): Female
# Determinato gender per Kit (Kit Gwin): Male
# Determinato gender per Zach (Zach Hopkins): Male
# Determinato gender per Eduardo (Eduardo Antonio Garcia): Male
# Determinato gender per Gene (Gene Jones): Male
# Determinato gender per Myk (Myk Watford): Male
# Determinato gender per Kathy (Kathy Lamkin): Female
# Determinato gender per Johnnie (Johnnie Hector): Male
# Determinato gender per Margaret (Margaret Bowman): Female
# Determinato gender per Thomas (Thomas Kopache): Male
# Determinato gender per Doris (Doris Hargrave): Female
# Determinato gender per Rutherford (Rutherford Cravens): Male
# Determinato gender per Matthew (Matthew Posey): Male
# Determinato gender per George (George Adelo): Male
# Determinato gender per Mathew (Mathew Greer): Male
# Determinato gender per Trent (Trent Moore): Male
# Determinato gender per Marc (Marc Miles): Male
# Determinato gender per Luce (Luce Rains): Female
# Determinato gender per Philip (Philip Bentham): Male
# Determinato gender per Chris (Chris Warner): Male
# Determinato gender per Brandon (Brandon Smith): Male
# Determinato gender per Roland (Roland Uribe): Male
# Determinato gender per Richard (Richard Jackson): Male
# Determinato gender per Josh (Josh Blaylock): Male
# Determinato gender per Dorsey (Dorsey Ray): Male
# Determinato gender per Angel (Angel H. Alvarado Jr.): Male
# Determinato gender per Scott (Scott Flick): Male
# Determinato gender per Spencer (Spencer Kayden): Male
# Determinato gender per Rachel (Rachel Manera): Female
# Determinato gender per Angelo (Angelo Martinez): Male
# Determinato gender per James (James Rishe): Male
# ['Ed', 'Anton', 'Llewelyn', 'Carson', 'Carla', 'Wendell', 'Loretta', 'Ellis', 'Man', 'El', 'Poolside', 'Sheriff', 'Strangled', 'Agua', 'Gas', 'Managerial', 'Desert', 'Cabbie', 'Del', 'Boot', 'Waitress', 'Gun', 'Sporting', 'Mexican', 'Hitchhiking', 'Nervous', 'Hotel', 'Pickup', 'Border', 'Flatbed', 'INS', 'Well', 'Chicken', 'Boy', 'Odessa', 'Norteño', 'Cab', 'Samantha', 'Pharmacy', 'Bus', 'Coffee']
# Scene del film No Country for Old Men inserite nel database.
# Determinato gender per Matthew (Matthew Macfadyen): Male
# Determinato gender per Eric (Eric MacLennan): Male
# Determinato gender per Kelly (Kelly Macdonald): Female
# Determinato gender per Theo (Theo Morrissey): Male
# Determinato gender per Cecily (Cecily Morrissey): Female
# Determinato gender per Freya (Freya Galpin): Female
# Determinato gender per Octavia (Octavia Morrissey): Female
# Determinato gender per Beatrice (Beatrice Morrissey): Female
# Determinato gender per Marine (Marine Battier): Female
# Determinato gender per Keira (Keira Knightley): Female
# Determinato gender per Guro (Guro Nagelhus Schia): Female
# Determinato gender per Aruhan (Aruhan Galieva): Female
# Determinato gender per Jude (Jude Law): Male
# Determinato gender per Carl (Carl Grose): Male
# Determinato gender per Bryan (Bryan Hands): Male
# Determinato gender per Oskar (Oskar McNamara): Male
# Determinato gender per Luke (Luke Newberry): Male
# Determinato gender per Olivia (Olivia Williams): Female
# Determinato gender per Michael (Michael Shaeffer): Male
# Determinato gender per Domhnall (Domhnall Gleeson): Male
# Determinato gender per Steven (Steven Beard): Male
# Determinato gender per Alicia (Alicia Vikander): Female
# Determinato gender per Pip (Pip Torrens): Female
# Determinato gender per Susanne (Susanne Lothar): Female
# Determinato gender per Henry (Henry Lloyd-Hughes): Male
# Determinato gender per Aaron (Aaron Taylor-Johnson): Male
# Determinato gender per David (David Wilmot): Male
# Determinato gender per Joseph (Joseph Macnab): Male
# Determinato gender per Nick (Nick Holder): Male
# Determinato gender per Claire (Claire Greenway): Female
# Determinato gender per Mike (Mike Shepherd): Male
# Determinato gender per Arthur (Arthur Nightingale): Male
# Determinato gender per Buffy (Buffy Davis): Female
# Determinato gender per Gala (Gala Wesson): Female
# Determinato gender per Eros (Eros Vlahos): Male
# Determinato gender per Kyle (Kyle Soller): Male
# Determinato gender per Sam (Sam Cox): Male
# Determinato gender per Max (Max Bennett): Male
# Determinato gender per Jude (Jude Monk McGowan): Male
# Determinato gender per Antony (Antony Byrne): Male
# Determinato gender per Sarine (Sarine Sofair): Female
# Determinato gender per Thomas (Thomas Howes): Male
# Determinato gender per Raphaël (Raphaël Personnaz): Male
# Determinato gender per Bill (Bill Skarsgård): Male
# Determinato gender per Hera (Hera Hilmar): Female
# Determinato gender per Steve (Steve Evets): Male
# Determinato gender per Conor (Conor McCarry): Male
# Determinato gender per Giles (Giles King): Male
# Determinato gender per Duncan (Duncan Wisbey): Male
# Determinato gender per Jamie (Jamie Beamish): Male
# Determinato gender per Nikolai (Nikolai Lester): Male
# Determinato gender per Philip (Philip Firsov): Male
# Determinato gender per Nicholas (Nicholas Blatt): Male
# Determinato gender per Greg (Greg Brummel): Male
# Determinato gender per Jensen (Jensen Freeman): Male
# Determinato gender per Dennis (Dennis Good): Male
# Determinato gender per Marina (Marina Hayter): Female
# Determinato gender per Inga (Inga Leps): Female
# Determinato gender per Vicky (Vicky McClure): Female
# Determinato gender per Katia (Katia Novitskaya-Kalai): Female
# Determinato gender per Tony (Tony Wood): Male
# ['Oblonsky', 'Matvey', 'Dolly', 'Grisha', 'Lili', 'Masha', 'Tanya', 'Vasya', 'Mlle', 'Anna', 'Annushka', 'Aruhan', 'Karenin', 'Korney', 'Mikhail', 'Serhoza', 'Vasily', 'Countess', 'Doorkeeper', 'Levin', 'Elderly', 'Kitty', 'Prince', 'Princess', 'Burisov', 'Vronsky', 'Nikolai', 'Guards', 'Stationmaster', 'Austrian', 'Wheel', 'Oblonskys', 'Agafia', 'Kitchen', 'Boris', 'Korsunsky', 'Kapitonich', 'Petritsky', 'Baroness', 'Tuskevitch', 'Colonel', 'Annas', 'Yashvin', 'Alexander', 'Makhotin', 'Varya', 'Theodore', 'Young', 'Stremov', 'Shopkeeper', 'Opera', 'Piano', 'Baby', 'Ball', 'Singing', 'Major', 'Office', 'Regimental', 'Ballroom', 'Foreign', 'Gallery', 'Girl', 'Victorian', 'Audience']
# Scene del film Anna Karenina inserite nel database.
# Determinato gender per Chiwetel (Chiwetel Ejiofor): Male
# Determinato gender per Dwight (Dwight Henry): Male
# Determinato gender per Dickie (Dickie Gravois): Male
# Determinato gender per Bryan (Bryan Batt): Male
# Determinato gender per Ashley (Ashley Dyke): Female
# Determinato gender per Kelsey (Kelsey Scott): Female
# Determinato gender per Cameron (Cameron Zeigler): Male
# Determinato gender per Tony (Tony Bentley): Male
# Determinato gender per Scoot (Scoot McNairy): Male
# Determinato gender per Taran (Taran Killam): Male
# Determinato gender per Christopher (Christopher Berry): Male
# Determinato gender per Bill (Bill Camp): Male
# Determinato gender per Chris (Chris Chalk): Male
# Determinato gender per Craig (Craig Tate): Male
# Determinato gender per Storm (Storm Reid): Male
# Determinato gender per Tom (Tom Proctor): Male
# Determinato gender per Marc (Marc Macaulay): Male
# Determinato gender per Vivian (Vivian Fleming-Alvarez): Female
# Determinato gender per Michael (Michael Kenneth Williams): Male
# Determinato gender per Douglas (Douglas M. Griffin): Male
# Determinato gender per John (John McConnell): Male
# Determinato gender per Marcus (Marcus Lyle Brown): Male
# Determinato gender per Richard (Richard Holden): Male
# Determinato gender per Rob (Rob Steinberg): Male
# Determinato gender per Paul (Paul Giamatti): Male
# Determinato gender per Benedict (Benedict Cumberbatch): Male
# Determinato gender per James (James C. Victor): Male
# Determinato gender per Liza (Liza J. Bennett): Female
# Determinato gender per Nicole (Nicole Collins): Female
# Determinato gender per JD (JD Evermore): Male
# Determinato gender per Paul (Paul Dano): Male
# Determinato gender per Michael (Michael Fassbender): Male
# Determinato gender per Lupita (Lupita Nyong'o): Female
# Determinato gender per Andy (Andy Dylan): Male
# Determinato gender per Deneen (Deneen Tyler): Female
# Determinato gender per Mustafa (Mustafa Harris): Male
# Determinato gender per Gregory (Gregory Bright): Male
# Determinato gender per Austin (Austin Purnell): Male
# Determinato gender per Thomas (Thomas Francis Murphy): Male
# Determinato gender per Andre (Andre De'Sean Shanks): Male
# Determinato gender per Scott (Scott Michael Jefferson): Male
# Determinato gender per Isaiah (Isaiah Jackson): Male
# Determinato gender per Garret (Garret Dillahunt): Male
# Determinato gender per Topsy (Topsy Chapman): Female
# Determinato gender per Brad (Brad Pitt): Male
# Determinato gender per Jay (Jay Huguley): Male
# Determinato gender per Willo (Willo Jean-Baptiste): Male
# Determinato gender per Blake (Blake Burt): Male
# Determinato gender per Carroll (Carroll Burt): Male
# Determinato gender per Joseph (Joseph Randy Causin): Male
# Determinato gender per Edward (Edward J. Clare): Male
# Determinato gender per Haylie (Haylie Creppel): Female
# Determinato gender per Emily (Emily D. Haley): Female
# Determinato gender per Mark (Mark Anthony Hardin): Male
# Determinato gender per Allyson (Allyson Leigh Jordan): Female
# Determinato gender per John (John C. Klein): Male
# Determinato gender per Elton (Elton LeBlanc): Male
# Determinato gender per Shawn (Shawn Parsons): Male
# Determinato gender per Chaz (Chaz Smith): Male
# Determinato gender per Tyler (Tyler Soerries): Male
# Determinato gender per Tre (Tre Tureaud): Male
# Determinato gender per Bob (Bob Walker): Male
# ['Solomon', 'Uncle', 'Overseer', 'Judge', 'Anna', 'Anne', 'Margaret', 'Alonzo', 'Mr', 'Brown', 'Hamilton', 'Burch', 'Radburn', 'Randall', 'Clemens', 'John', 'Eliza', 'Emily', 'Biddee', 'Captain', 'Mulatto', 'Robert', 'Sailor', 'Jonus', 'Jasper', 'Fitzgerald', 'Parker', 'Freeman', 'Cape', 'Ford', 'Buyeras', 'Mistress', 'Rachel', 'Chapin', 'Tibeats', 'Edwin', 'Patsey', 'Treach', 'Phebeas', 'Sam', 'Edward', 'Bob', 'Patroller', 'Victim', 'Master', 'Zachary', 'Armsby', 'Slave', 'Bass', 'Sheriff', 'Margarets', 'Northern', 'Upper', 'Lower', 'Washington', 'Steamboat', 'Restaurant', 'Child', 'Tea', 'Street', 'Ballroom', 'Lumber', 'Hotel', 'Road', 'Cigar', 'Boy', 'Saratoga', 'Abolitionist']
# Scene del film 12 Years a Slave inserite nel database.
# Determinato gender per Lisa (Lisa Adam): Female
# Determinato gender per Frank (Frank Aldridge): Male
# Determinato gender per Amitabh (Amitabh Bachchan): Male
# Determinato gender per Steve (Steve Bisley): Male
# Determinato gender per Richard (Richard Carter): Male
# Determinato gender per Jason (Jason Clarke): Male
# Determinato gender per Adelaide (Adelaide Clemens): Female
# Determinato gender per Vince (Vince Colosimo): Male
# Determinato gender per Max (Max Cullen): Male
# Determinato gender per Elizabeth (Elizabeth Debicki): Female
# Determinato gender per Leonardo (Leonardo DiCaprio): Male
# Determinato gender per Joel (Joel Edgerton): Male
# Determinato gender per Emmanuel (Emmanuel Ekwensi): Male
# Determinato gender per Eden (Eden Falk): Female
# Determinato gender per Isla (Isla Fisher): Female
# Determinato gender per Emily (Emily Foreman): Female
# Determinato gender per Garrett (Garrett William Fountain): Male
# Determinato gender per David (David Furlong): Male
# Determinato gender per Daniel (Daniel Gill): Male
# Determinato gender per Price (Price Johnson): Male
# Determinato gender per Stephen (Stephen James King): Male
# Determinato gender per Goran (Goran D. Kleut): Male
# Determinato gender per Kim (Kim Knuckey): Female
# Determinato gender per Barrie (Barrie Laws): Male
# Determinato gender per Brendan (Brendan Maclean): Male
# Determinato gender per Tobey (Tobey Maguire): Male
# Determinato gender per Callan (Callan McAuliffe): Male
# Determinato gender per Ben (Ben McIvor): Male
# Determinato gender per Kevin (Kevin McGlothan): Male
# Determinato gender per Nick (Nick Meenahan): Male
# Determinato gender per Olga (Olga Miller): Female
# Determinato gender per Heather (Heather Mitchell): Female
# Determinato gender per Carey (Carey Mulligan): Female
# Determinato gender per Gus (Gus Murray): Male
# Determinato gender per Kate (Kate Mulvany): Female
# Determinato gender per Barry (Barry Otto): Male
# Determinato gender per John (John O'Connell): Male
# Determinato gender per Corey (Corey Blake Owers): Male
# Determinato gender per Tasman (Tasman Palazzi): Male
# Determinato gender per Brenton (Brenton Prince): Male
# Determinato gender per Bryan (Bryan Probets): Male
# Determinato gender per Milan (Milan Pulvermacher): Male
# Determinato gender per Jake (Jake Ryan): Male
# Determinato gender per Nicholas (Nicholas Simpson): Male
# Determinato gender per Kasia (Kasia Stelmach): Female
# Determinato gender per Nick (Nick Tate): Male
# Determinato gender per Jack (Jack Thompson): Male
# Determinato gender per Kieran (Kieran van Bunnik): Male
# Determinato gender per Sylvana (Sylvana Vandertouw): Female
# Determinato gender per Gemma (Gemma Ward): Female
# Determinato gender per Matthew (Matthew Whittet): Male
# Determinato gender per Felix (Felix Williamson): Male
# Determinato gender per Bill (Bill Young): Male
# Determinato gender per Nancy (Nancy Denis): Female
# Determinato gender per Natasha (Natasha Marconi): Female
# Determinato gender per Tiana (Tiana Canterbury): Female
# Determinato gender per Effie (Effie Nkrumah): Female
# Determinato gender per Donna (Donna Stevens): Female
# Determinato gender per Alison (Alison Benstead): Female
# Determinato gender per Jeremy (Jeremy Costello): Male
# Determinato gender per Jeff (Jeff Duff): Male
# Determinato gender per Simon (Simon Edds): Male
# Determinato gender per Rhianne (Rhianne Evelyn-Ross): Female
# Determinato gender per Conor (Conor Fogarty): Male
# Determinato gender per Paul (Paul Godfrey): Male
# Determinato gender per Lara (Lara Goldie): Female
# Determinato gender per Nigel (Nigel Harbach): Male
# Determinato gender per Alex (Alex Lissine): Male
# Determinato gender per Kate (Kate Little): Female
# Determinato gender per Jesse (Jesse McGoldrick): Male
# Determinato gender per Rowan (Rowan Moses): Female
# Determinato gender per Jey (Jey Oz): Male
# Determinato gender per Eddie (Eddie Ritchard): Male
# Determinato gender per Alexander (Alexander Roberts): Male
# Determinato gender per Bruno (Bruno Stephane): Male
# ['WeepingSinging', 'Well', 'Meyer', 'Dan', 'Herzog', 'George', 'Catherine', 'Michaelis', 'Owl', 'Jordan', 'Jay', 'Tom', 'Jazz', 'Mr', 'Myrtle', 'Pammy', 'Barman', 'Walter', 'Police', 'Trimalchio', 'Singer', 'Nelson', 'Head', 'Senator', 'Party', 'Klipspringer', 'Nick', 'Teen', 'Clerk', 'Footman', 'Train', 'Russian', 'Daisys', 'Daisy', 'Teddy', 'Mrs', 'Benny', 'Newton', 'Louisville', 'Young', 'Guard', 'Gardener', 'Waiter', 'Motorcycle', 'Second', 'Silent', 'Taxi', 'Dr', 'Rowdie', 'European', 'Languid', 'Vladimir', 'Henrí', 'Policeman', 'Foxy', 'Puff', 'Speakeasy', 'Dancing', 'Trapeze', 'Anita', 'Beach', 'Clarence', 'Probity', 'West', 'Gatsbys', 'Maurice', 'Woman', 'Ripley', 'Cocktail', 'Laurette', 'Bennys', 'Gertrude', 'Wolfsheim', 'Drowned', 'Gatsby', 'Elsie', 'Henrivoice']
# Scene del film Great Gatsby, The inserite nel database.
# Determinato gender per Ellen (Ellen Burstyn): Female
# Determinato gender per Matthew (Matthew McConaughey): Male
# Determinato gender per John (John Lithgow): Male
# Determinato gender per Timothée (Timothée Chalamet): Male
# Determinato gender per David (David Oyelowo): Male
# Determinato gender per Collette (Collette Wolfe): Female
# Determinato gender per Francis (Francis X. McCarthy): Male
# Determinato gender per Bill (Bill Irwin): Male
# Determinato gender per Anne (Anne Hathaway): Female
# Determinato gender per Andrew (Andrew Borba): Male
# Determinato gender per Wes (Wes Bentley): Male
# Determinato gender per William (William Devane): Male
# Determinato gender per Michael (Michael Caine): Male
# Determinato gender per David (David Gyasi): Male
# Determinato gender per Josh (Josh Stewart): Male
# Determinato gender per Leah (Leah Cairns): Female
# Determinato gender per Liam (Liam Dickinson): Male
# Determinato gender per Topher (Topher Grace): Male
# Determinato gender per Matt (Matt Damon): Male
# Determinato gender per Flora (Flora Nolan): Female
# Determinato gender per Griffen (Griffen Fraser): Male
# Determinato gender per Jeff (Jeff Hephner): Male
# Determinato gender per Lena (Lena Georgas): Female
# Determinato gender per Elyes (Elyes Gabel): Male
# Determinato gender per Russ (Russ Fega): Male
# Determinato gender per William (William Patrick Brown): Male
# Determinato gender per Troy (Troy Fyhn): Male
# Determinato gender per Alexander (Alexander Michael Helisek): Male
# Determinato gender per Ryan (Ryan Irving): Male
# Determinato gender per Derek (Derek McEntire): Male
# ['Murph', 'Cooper', 'Donald', 'Tom', 'School', 'Ms', 'Bootsas', 'TARSvoice', 'Brand', 'Smith', 'Doyle', 'Williams', 'Professor', 'Romilly', 'CASEvoice', 'Lois', 'Coop', 'Getty', 'Mann', 'Girl', 'Boy', 'Doctor', 'Nurse', 'Administrator', 'Crew', 'NASA', 'Baseball', 'Construction', 'Popcorn', 'Murphs']
# Scene del film Interstellar inserite nel database.
# Determinato gender per Bradley (Bradley Cooper): Male
# Determinato gender per Kyle (Kyle Gallner): Male
# Determinato gender per Cole (Cole Konis): Male
# Determinato gender per Ben (Ben Reed): Male
# Determinato gender per Elise (Elise Robertson): Female
# Determinato gender per Troy (Troy Vincent): Male
# Determinato gender per Brandon (Brandon Salgado Telis): Male
# Determinato gender per Keir (Keir O'Donnell): Male
# Determinato gender per Jason (Jason Hall): Male
# Determinato gender per Billy (Billy Miller): Male
# Determinato gender per Leonard (Leonard Roberts): Male
# Determinato gender per Reynaldo (Reynaldo Gallegos): Male
# Determinato gender per Kevin (Kevin Lacz): Male
# Determinato gender per Jake (Jake McDorman): Male
# Determinato gender per Cory (Cory Hardrict): Male
# Determinato gender per Eric (Eric Ladin): Male
# Determinato gender per Sienna (Sienna Miller): Female
# Determinato gender per Brando (Brando Eaton): Male
# Determinato gender per James (James Ryen): Male
# Determinato gender per Luke (Luke Grimes): Male
# Determinato gender per Sammy (Sammy Sheik): Male
# Determinato gender per Kevin (Kevin Ryan): Male
# Determinato gender per Evan (Evan Gamble): Male
# Determinato gender per Tim (Tim Griffin): Male
# Determinato gender per Luis (Luis Jose Lopez): Male
# Determinato gender per Brian (Brian Hallisay): Male
# Determinato gender per Erik (Erik Aude): Male
# Determinato gender per Jad (Jad Mhidi Senhaji): Male
# Determinato gender per Navid (Navid Negahban): Male
# Determinato gender per Fehd (Fehd Benchemsi): Male
# Determinato gender per Eric (Eric Close): Male
# Determinato gender per Zack (Zack Duhame): Male
# Determinato gender per Kathe (Kathe Mazur): Female
# Determinato gender per Chance (Chance Kelly): Male
# Determinato gender per Ryan (Ryan Sadaghiani): Male
# Determinato gender per Ayman (Ayman Samman): Male
# Determinato gender per Fahim (Fahim Fazli): Male
# Determinato gender per Salah (Salah Salea): Male
# Determinato gender per Hector (Hector Bucio): Male
# Determinato gender per Melissa (Melissa Hayden): Female
# Determinato gender per Mark (Mark Thomason): Male
# Determinato gender per Quay (Quay Terry): Male
# Determinato gender per James (James D. Dever): Male
# Determinato gender per Joel (Joel Lambert): Male
# Determinato gender per Owain (Owain Yeoman): Male
# Determinato gender per Tony (Tony Nevada): Male
# Determinato gender per Ricky (Ricky Ryba): Male
# Determinato gender per Greg (Greg Duke): Male
# Determinato gender per Max (Max Charles): Male
# Determinato gender per Jet (Jet Jurgensmeyer): Male
# Determinato gender per Madeleine (Madeleine McGraw): Female
# Determinato gender per Elizabeth (Elizabeth Schmidt): Female
# Determinato gender per Robert (Robert Clotworthy): Male
# Determinato gender per Bryan (Bryan Anderson): Male
# Determinato gender per Jacob (Jacob Schick): Male
# Determinato gender per Wade (Wade White): Male
# Determinato gender per Brad (Brad Abrell): Male
# Determinato gender per Robert (Robert Aldredge): Male
# Determinato gender per Amber (Amber Alexander): Female
# Determinato gender per Ethan (Ethan C. Avery): Male
# Determinato gender per Sarah (Sarah Beaver): Female
# Determinato gender per Rowdy (Rowdy Brown): Male
# Determinato gender per Ryan (Ryan Christiansen): Male
# Determinato gender per Mark (Mark DeSalvo): Male
# Determinato gender per Savannah (Savannah Douglas): Female
# Determinato gender per Clint (Clint Eastwood): Male
# Determinato gender per Jay (Jay Eftimoski): Male
# Determinato gender per Brent (Brent Gutierrez): Male
# Determinato gender per Alissa (Alissa Jessup): Female
# Determinato gender per Noëlle (Noëlle Lara): Female
# Determinato gender per Jon (Jon Maxwell): Male
# Determinato gender per Katie (Katie Meschke): Female
# Determinato gender per Katia (Katia Peel): Female
# Determinato gender per Cristal (Cristal Peshkepia): Female
# Determinato gender per Haley (Haley Bri Powell): Female
# Determinato gender per Michael (Michael Prather): Male
# Determinato gender per Jon (Jon Ray): Male
# Determinato gender per Radcliff (Radcliff Redding): Male
# Determinato gender per Will (Will Rian): Male
# Determinato gender per Jane (Jane Runnalls): Female
# Determinato gender per Amanda (Amanda Sackett): Female
# Determinato gender per Katherine (Katherine Stephens-Miller): Female
# ['Chris', 'GoatWinston', 'Young', 'Wayne', 'Deby', 'Pastor', 'Bullyas', 'Jeff', 'Sarah', 'Cowboy', 'Navy', 'Instructor', 'Tonyas', 'Dauber', 'Biggles', 'DDandridge', 'SquirrelCase', 'Taya', 'Dapper', 'PO', 'Marc', 'Mustafa', 'Marine', 'JAG', 'Colonel', 'Sanchez', 'Capt', 'Thompson', 'Omar', 'Sheikh', 'Terp', 'DIA', 'Contractor', 'Dr', 'Lt', 'Son', 'Father', 'Messianic', 'Angry', 'PFC', 'Receptionist', 'Chaplain', 'Firing', 'Funeral', 'Delta', 'Ranger', 'Recon', 'Cobra', 'MRAP', 'Colton', 'Coltons', 'McKenna', 'Boys', 'VA', 'Wynns', 'Wynn', 'Veteran', 'September', 'Sniper', 'Drinking', 'US', 'Soldiers', 'Bull', 'Cop', 'Col', 'Playground', 'Church', 'Rodeo', 'Humvee', 'Car', 'Female', 'Bar', 'American', 'Wedding', 'Private', 'Little', 'Woman', 'Kidvoice', 'Family', 'Black', 'Homecoming', 'Major', 'Carjacker', 'Jiffy', 'Maid', 'Relative']
# Scene del film American Sniper inserite nel database.
# Determinato gender per Ryan (Ryan Gosling): Male
# Determinato gender per Emma (Emma Stone): Female
# Determinato gender per Amiee (Amiee Conn): Female
# Determinato gender per Terry (Terry Walters): Male
# Determinato gender per Thom (Thom Shelton): Male
# Determinato gender per Cinda (Cinda Adams): Female
# Determinato gender per Callie (Callie Hernandez): Female
# Determinato gender per Jessica (Jessica Rothe): Female
# Determinato gender per Rosemarie (Rosemarie DeWitt): Female
# Determinato gender per Claudine (Claudine Claudio): Female
# Determinato gender per Jason (Jason Fuchs): Male
# Determinato gender per Mike (Mike Fallin): Male
# Determinato gender per Trevor (Trevor Lissauer): Male
# Determinato gender per Olivia (Olivia Hamilton): Female
# Determinato gender per Anna (Anna Chazelle): Female
# Determinato gender per Marius (Marius De Vries): Male
# Determinato gender per Finn (Finn Wittrock): Male
# Determinato gender per Josh (Josh Pence): Male
# Determinato gender per Nicole (Nicole Coulon): Female
# Determinato gender per Damon (Damon Gupton): Male
# Determinato gender per John (John Legend): Male
# Determinato gender per Christopher (Christopher Michael Stevens): Male
# Determinato gender per Keith (Keith Harris): Male
# Determinato gender per Kaveh (Kaveh Rastegar): Male
# Determinato gender per David (David Douglas): Male
# Determinato gender per Miles (Miles Anderson): Male
# Determinato gender per Bobo (Bobo Chang): Male
# Determinato gender per Meagen (Meagen Fay): Female
# Determinato gender per Robert (Robert Haynes): Male
# Determinato gender per John (John Hindman): Male
# Determinato gender per Valarie (Valarie Rae Miller): Female
# Determinato gender per Corrin (Corrin Evans): Female
# Determinato gender per Tom (Tom Everett Scott): Male
# Determinato gender per Zoë (Zoë Hall): Female
# Determinato gender per Dempsey (Dempsey Pappion): Male
# Determinato gender per Arthur (Arthur Horowitz): Male
# Determinato gender per Reshma (Reshma Gajjar): Female
# Determinato gender per Tracy (Tracy Shibata): Female
# Determinato gender per Ava (Ava Bernstine): Female
# Determinato gender per Samantha (Samantha Abrantes): Female
# Determinato gender per Drew (Drew Bayers): Male
# Determinato gender per Kayla (Kayla Bechor): Female
# Determinato gender per Cameron (Cameron Brinkman): Male
# Determinato gender per Alex (Alex Budman): Male
# Determinato gender per Morgan (Morgan Cohen): Male
# Determinato gender per Lindsay (Lindsay DeLuca): Female
# Determinato gender per Brandi (Brandi Erin Douglas): Female
# Determinato gender per Kristin (Kristin Elliott): Female
# Determinato gender per Amanda (Amanda Fields): Female
# Determinato gender per Ana (Ana Flavia Gavlak): Female
# Determinato gender per Sascha (Sascha Ghafoor): Male
# Determinato gender per Sai (Sai Gundewar): Male
# Determinato gender per Darrell (Darrell Keith Harris): Male
# Determinato gender per Matthew (Matthew Herington): Male
# Determinato gender per Kelly (Kelly Kennedy): Female
# Determinato gender per David (David Kieran): Male
# Determinato gender per Stanley (Stanley Kowalski): Male
# Determinato gender per Jacques (Jacques Lesure): Male
# Determinato gender per Bunny (Bunny Levine): Male
# Determinato gender per Elaine (Elaine Lockhart): Female
# Determinato gender per Kaye (Kaye L. Morris): Female
# Determinato gender per Tommy (Tommy Otis): Male
# Determinato gender per Clarence (Clarence Robinson): Male
# Determinato gender per Paul (Paul Mitchell Rosenblum): Male
# Determinato gender per Sam (Sam Stone): Male
# Determinato gender per Jeremy (Jeremy Nathan Tisser): Male
# Determinato gender per Bijon (Bijon Watson): Male
# Determinato gender per Ian (Ian Wolfe): Male
# Determinato gender per Ishah (Ishah Laurah Wright): Female
# ['Sebastian', 'Mia', 'Famous', 'Linda', 'Coffee', 'Casting', 'Tracy', 'Alexis', 'Caitlin', 'Laura', 'Bill', 'Karen', 'Carlo', 'Free', 'Valet', 'Bree', 'Sarah', 'Clyde', 'Greg', 'Josh', 'Joshs', 'Harry', 'Keith', 'Malcolm', 'Cole', 'Tom', 'Echo', 'Radio', 'Alistair', 'Photographers', 'Mias', 'Angry', 'Frank', 'Amy', 'New', 'David', 'Chelsea', 'Sebs', 'Fantasy', 'Traffic', 'Hollywood', 'Restaurant', 'Epilogue', 'Laptop', 'Street', 'Jazz', 'Flute', 'Kissing', 'Dream', 'French', 'Audition', 'Red', 'Young', 'Concert', 'Cafe', 'Swing', 'Film', 'Bubblegum', 'Theater', 'Party', 'Club', 'Movie', 'Wedding', 'Producers', 'Extra', 'Lighthouse', 'Drunk', 'Another', 'Espresso', 'Freeway', 'Nightclub', 'Dr', 'Tap']
# Scene del film La La Land inserite nel database.
